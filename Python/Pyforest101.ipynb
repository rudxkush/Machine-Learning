# %% [markdown]
# <a href="https://colab.research.google.com/github/rudxkush/Machine-Learning/blob/main/Python/Pyforest101.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Pyforest - Lazy import for all python DS libs

# %%
# !pip install Pyforest

# %%
import pyforest

# %%
from google.colab import files

uploaded = files.upload()  # choose your .csv file
# Out:
#      <input type="file" id="files-f369db98-5ce6-40c5-b21f-53b71630f0c2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f369db98-5ce6-40c5-b21f-53b71630f0c2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('olympic-medals.csv')

# %%
df.head(10)
# Out:
#   Country_Code    Country_Name Medal_Type  Count
# 0          USA   United States       Gold     46
# 1          USA   United States     Silver     29
# 2          USA   United States     Bronze     29
# 3          CHN           China       Gold     38
# 4          CHN           China     Silver     27
# 5          CHN           China     Bronze     23
# 6          RUS          Russia       Gold     24
# 7          RUS          Russia     Silver     26
# 8          RUS          Russia     Bronze     32
# 9          GBR  United Kingdom       Gold     29

# %%
df.select_dtypes(include='number').corr()  # Compute correlations only for numeric columns
# Out:
#        Count
# Count    1.0

# %%
active_imports()
# Out:
# from sklearn.decomposition import PCA
# import textblob
# import xgboost as xgb
# from pathlib import Path
# import matplotlib.pyplot as plt
# from sklearn import metrics
# import re
# from sklearn.feature_extraction.text import CountVectorizer
# from sklearn.linear_model import Ridge
# import os
# import pickle
# import pydot
# import lightgbm as lgb
# from sklearn import svm
# from sklearn.manifold import TSNE
# import plotly.graph_objs as go
# from sklearn.preprocessing import LabelEncoder
# from sklearn.model_selection import train_test_split
# from sklearn.model_selection import GridSearchCV
# from statsmodels.tsa.arima_model import ARIMA
# from sklearn.linear_model import ElasticNet
# import plotly as py
# from sklearn.preprocessing import PolynomialFeatures
# from sklearn.impute import SimpleImputer
# import altair as alt
# import nltk
# import plotly.express as px
# import keras
# import spacy
# from scipy import stats
# ...

# %%
lst1 = [1, 2, 4, 6, 9]
lst2 = [9, 2, 4, 1, 2]
plt.plot(lst1, lst2)
plt.show()
